# %%
# %load_ext lab_black
import ccxt
import time
import numpy as np
import pandas as pd
# Out:
# The lab_black extension is already loaded. To reload it, use:
#   %reload_ext lab_black

# %%
# ccxt.exchanges

# %%
huobipro = ccxt.huobipro()
# huobipro.load_markets()

# %%
# Ticker data
data = huobipro.fetchTicker(symbol="BTC/USDT")

# %%
# K graph data
data = huobipro.fetch_ohlcv(symbol="BTC/USDT", timeframe="1h", limit=2000)
header = ["Timestamp", "Open", "High", "Low", "Close", "Volume"]
df = pd.DataFrame(data, columns=header)
df["Timestamp"] = pd.to_datetime(df["Timestamp"], unit="ms")
df = df.sort_values(by="Timestamp")
df["Number"] = np.arange(len(df)) + 1
df = df.set_index("Number")
df
# Out:
#                  Timestamp      Open      High       Low     Close  \
# Number
# 1      2021-01-12 22:00:00  34723.33  35100.00  33351.11  33752.14
# 2      2021-01-12 23:00:00  33754.05  34136.98  33300.00  34048.59
# 3      2021-01-13 00:00:00  34048.59  34048.60  32366.00  32528.28
# 4      2021-01-13 01:00:00  32528.28  33258.15  32470.72  33124.39
# 5      2021-01-13 02:00:00  33120.11  33551.68  32565.43  33039.24
# ...                    ...       ...       ...       ...       ...
# 1996   2021-04-06 01:00:00  59365.90  59500.00  58743.30  58813.64
# 1997   2021-04-06 02:00:00  58811.37  58880.01  58650.99  58752.17
# 1998   2021-04-06 03:00:00  58755.81  58950.00  58606.39  58616.81
# 1999   2021-04-06 04:00:00  58616.82  58890.53  58616.80  58793.91
# 2000   2021-04-06 05:00:00  58793.91  59031.19  58759.07  58908.71
#
#              Volume
# Number
# 1       1979.483352
# 2       3073.243902
# 3       5284.854001
# 4       3413.044687
# 5       3347.811642
# ...

# %%
# df = pd.DataFrame({
#    'pig': [20, 18, 489, 675, 1776],
#    'horse': [4, 25, 281, 600, 1900]
#    }, index=[1990, 1997, 2003, 2009, 2014])
# lines = df[["Low", "High", "Close"]].plot.line(figsize=(30, 10))
lines = df["Close"].plot.line(figsize=(30, 10))
lines
# Out:
# <AxesSubplot:xlabel='Number'>

# %%
# huobipro.fetch_trades("BTC/USDT")

# %%
exchange.load_markets()
symbol = "BTC/USDT"
amount = 1.2345678  # amount in base currency BTC
price = 87654.321  # price in quote currency USDT
formatted_amount = exchange.amount_to_precision(symbol, amount)
formatted_price = exchange.price_to_precision(symbol, price)
print(formatted_amount, formatted_price)
# Out:
# 1.234567 87654.32

# %%
import pandas as pd

df = pd.concat([pd.Series(x) for x in data], axis=1)

# %%
df
# Out:
#            0             1             2             3             4     \
# 0  1.610482e+12  1.610485e+12  1.610489e+12  1.610492e+12  1.610496e+12
# 1  3.467880e+04  3.427498e+04  3.472333e+04  3.375405e+04  3.404859e+04
# 2  3.468393e+04  3.488981e+04  3.510000e+04  3.413698e+04  3.404860e+04
# 3  3.372419e+04  3.381436e+04  3.335111e+04  3.330000e+04  3.236600e+04
# 4  3.427968e+04  3.472636e+04  3.375214e+04  3.404859e+04  3.252828e+04
# 5  1.984699e+03  1.863817e+03  1.979483e+03  3.073244e+03  5.284854e+03
#
#            5             6             7             8             9     ...  \
# 0  1.610500e+12  1.610503e+12  1.610507e+12  1.610510e+12  1.610514e+12  ...
# 1  3.252828e+04  3.312011e+04  3.303924e+04  3.382107e+04  3.318537e+04  ...
# 2  3.325815e+04  3.355168e+04  3.442784e+04  3.391435e+04  3.351800e+04  ...
# 3  3.247072e+04  3.256543e+04  3.298858e+04  3.308680e+04  3.280562e+04  ...
# 4  3.312439e+04  3.303924e+04  3.381737e+04  3.318583e+04  3.331975e+04  ...
# ...

# %%
df = df.T

# %%
df.columns = ["TimeStamp", "Open", "High", "Low", "Close", "Volume"]

# %%
df
# Out:
#          TimeStamp      Open      High       Low     Close       Volume
# 0     1.610482e+12  34678.80  34683.93  33724.19  34279.68  1984.699017
# 1     1.610485e+12  34274.98  34889.81  33814.36  34726.36  1863.816767
# 2     1.610489e+12  34723.33  35100.00  33351.11  33752.14  1979.483352
# 3     1.610492e+12  33754.05  34136.98  33300.00  34048.59  3073.243902
# 4     1.610496e+12  34048.59  34048.60  32366.00  32528.28  5284.854001
# ...            ...       ...       ...       ...       ...          ...
# 1995  1.617664e+12  58877.24  59133.12  58547.40  59133.11   600.690603
# 1996  1.617667e+12  59133.12  59480.00  59048.31  59365.90  1063.962303
# 1997  1.617671e+12  59365.90  59500.00  58743.30  58813.64   930.230627
# 1998  1.617674e+12  58811.37  58880.01  58650.99  58752.17   518.815840
# 1999  1.617678e+12  58755.81  58858.88  58729.98  58810.39    69.567986
#
# [2000 rows x 6 columns]

# %%
df.to_csv("Huobi_BTC_1h.csv")

# %%
from datetime import datetime

df["TimeStamp"] = pd.to_datetime(df["TimeStamp"])

# %%
df
# Out:
#                       TimeStamp      Open      High       Low     Close  \
# 0    1970-01-01 00:26:50.481600  34678.80  34683.93  33724.19  34279.68
# 1    1970-01-01 00:26:50.485200  34274.98  34889.81  33814.36  34726.36
# 2    1970-01-01 00:26:50.488800  34723.33  35100.00  33351.11  33752.14
# 3    1970-01-01 00:26:50.492400  33754.05  34136.98  33300.00  34048.59
# 4    1970-01-01 00:26:50.496000  34048.59  34048.60  32366.00  32528.28
# ...                         ...       ...       ...       ...       ...
# 1995 1970-01-01 00:26:57.663600  58877.24  59133.12  58547.40  59133.11
# 1996 1970-01-01 00:26:57.667200  59133.12  59480.00  59048.31  59365.90
# 1997 1970-01-01 00:26:57.670800  59365.90  59500.00  58743.30  58813.64
# 1998 1970-01-01 00:26:57.674400  58811.37  58880.01  58650.99  58752.17
# 1999 1970-01-01 00:26:57.678000  58755.81  58858.88  58729.98  58810.39
#
#            Volume
# 0     1984.699017
# 1     1863.816767
# 2     1979.483352
# 3     3073.243902
# ...
