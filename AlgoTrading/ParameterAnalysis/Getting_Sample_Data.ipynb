# %%
# %load_ext lab_black
# %config Completer.use_jedi = False
import pandas as pd
from tqdm import tqdm
import time
# Out:
# The lab_black extension is already loaded. To reload it, use:
#   %reload_ext lab_black

# %%
# FILENAME = "Binance_BTC_1m.csv"
# FILENAME = "Mild_Fluctuate_data.csv"
# FILENAME = "Increasing_Data.csv"
FILENAME = "Decreasing_Data.csv"
data = pd.read_csv(FILENAME)
data = data[5000:]
data
# Out:
#        Unnamed: 0  Unnamed: 0.1        TimeStamp      Open      High  \
# 5000       125000        135620  2021/2/21 12:52  56530.69  56571.77
# 5001       125001        135621  2021/2/21 12:53  56526.38  56590.00
# 5002       125002        135622  2021/2/21 12:54  56550.00  56640.00
# 5003       125003        135623  2021/2/21 12:55  56604.55  56613.83
# 5004       125004        135624  2021/2/21 12:56  56572.71  56631.11
# ...           ...           ...              ...       ...       ...
# 19995      139995        113194   2021/2/5 21:47  37963.72  37999.68
# 19996      139996        113195   2021/2/5 21:48  37978.08  38130.17
# 19997      139997        113196   2021/2/5 21:49  38127.43  38198.78
# 19998      139998        113197   2021/2/5 21:50  38172.02  38172.03
# 19999      139999        113198   2021/2/5 21:51  38137.56  38141.20
#
#             Low     Close      Volume
# 5000   56523.90  56526.38   17.928238
# 5001   56517.00  56550.01   25.635945
# 5002   56542.94  56604.54   19.254883
# 5003   56541.25  56569.16   18.708440
# 5004   56544.52  56623.46   19.152437
# ...         ...       ...         ...
# 19995  37963.71  37978.09   89.867376
# 19996  37971.29  38130.00  178.493656
# 19997  38084.69  38172.03  211.731013
# 19998  38079.23  38140.94  158.094804
# 19999  38075.29  38110.48   92.377754
#
# [15000 rows x 8 columns]

# %%
import matplotlib.pyplot as plt

# %matplotlib inline
fig, ax = plt.subplots(figsize=(30, 10))
# plt.ylim(0, 100)
data[["Close"]].plot(ax=ax)
# Out:
# <AxesSubplot:>

# %%
# data.to_csv("Decreasing_Data.csv")
