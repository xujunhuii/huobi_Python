# %%
# %load_ext lab_black
# %config Completer.use_jedi = False
import pandas as pd
from Grid_Tuning_geometric import grid_trading, speedy_grid_trading
from tqdm import tqdm
import time

# %%
# %%time

# FILENAME = "Mild_Fluctuate_data.csv"
FILENAME = "Increasing_Data.csv"
data = pd.read_csv(FILENAME)
optimization=[]
# for interval_for_bounds in tqdm(range(5,20)):
#     for sd in range(2,5):
#         records_df, final_profit = speedy_grid_trading(
#             data, INTERVAL_FOR_BOUNDS=interval_for_bounds * 24 * 60, SD_PARAMETER=sd,
#         )
#         optimization.append([final_profit, "", interval_for_bounds, sd])
# Out:
# Wall time: 67 ms

# %%
# optimization=[]
# for interval_for_rsv in tqdm(range(10, 60)):
#     for interval_for_bounds in range(2, 20):
#         for sd_parameter in range(2,5):
#             records_df, final_profit = grid_trading(
#                 data, INTERVALS_FOR_RSV=interval_for_rsv, INTERVAL_FOR_BOUNDS=interval_for_bounds * 24 * 60, SD_PARAMETER=sd_parameter,
#             )
#             optimization.append([final_profit, interval_for_rsv, interval_for_bounds, sd_parameter])
#             print(time.ctime())

# %%
optimization_df = pd.DataFrame(
    optimization,
    columns=["FinalProfit", "IntervalForRSV", "IntervalForBounds", "SDParameter",],
)

# %%
# optimization_df.to_excel("Geometric_Sequence_Training_Parameters.xlsx")
# optimization_df = pd.read_excel("Training.xlsx")
optimization_df
# Out:
#     FinalProfit IntervalForRSV  IntervalForBounds  SDParameter
# 0        146083                                 5            2
# 1        152521                                 5            3
# 2        113419                                 5            4
# 3        129581                                 6            2
# 4        120412                                 6            3
# 5        105766                                 6            4
# 6        134226                                 7            2
# 7        124318                                 7            3
# 8        111756                                 7            4
# 9        128901                                 8            2
# 10       111604                                 8            3
# 11       114050                                 8            4
# 12       134532                                 9            2
# 13       121695                                 9            3
# 14       120476                                 9            4
# 15       125333                                10            2
# 16       114289                                10            3
# 17       126836                                10            4
# 18       105352                                11            2
# 19       110367                                11            3
# 20       121966                                11            4
# 21        98945                                12            2
# 22       101481                                12            3
# 23       104411                                12            4
# 24       108350                                13            2
# 25       106021                                13            3
# 26       112721                                13            4
# 27       115603                                14            2
# 28       109425                                14            3
# 29       127460                                14            4
# 30       175860                                15            2
# 31       111953                                15            3
# 32       112201                                15            4
# 33       135392                                16            2
# 34        98963                                16            3
# 35       131530                                16            4
# 36       146562                                17            2
# 37       101003                                17            3
# 38       123926                                17            4
# 39       130927                                18            2
# 40       113972                                18            3
# 41       124300                                18            4
# 42       128440                                19            2
# 43       116183                                19            3
# 44       110768                                19            4

# %%
df = optimization_df[
    optimization_df["FinalProfit"] == optimization_df["FinalProfit"].max()
]
SDParameter = df["SDParameter"].unique()
IntervalForBounds = df["IntervalForBounds"].unique()
IntervalForRSV = df["IntervalForRSV"].unique()
FinalProfit = df["FinalProfit"].unique()

# %%
SDParameter
# Out:
# array([2], dtype=int64)

# %%
IntervalForBounds
# Out:
# array([15], dtype=int64)

# %%
IntervalForRSV
# Out:
# array([''], dtype=object)

# %%
FinalProfit
# Out:
# array([175860], dtype=int64)

# %%
# %%time
from Grid_Tuning_geometric import grid_trading, speedy_grid_trading
FILENAME = "Decreasing_Data.csv"
data = pd.read_csv(FILENAME)
records_df, final_profit = speedy_grid_trading(
    data, INTERVAL_FOR_BOUNDS=15 * 24 * 60, SD_PARAMETER=2,
)
records_df["Hour"] = pd.to_datetime(records_df["Hour"])
records_df
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <timed exec> in <module>
#
# ~\Documents\GitHub\huobi_Python\AlgoTrading\ParameterAnalysis\Grid_Tuning_geometric.py in speedy_grid_trading(data, INTERVAL_FOR_BOUNDS, SD_PARAMETER)
#     160     data.reset_index(drop=True, inplace=True)
#     161     records = transact(data)
# --> 162     records_df = generate_records_df(records)
#     163     final_profit = get_final_profit(records_df)
#     164     return records_df, final_profit
#
# ~\Documents\GitHub\huobi_Python\AlgoTrading\ParameterAnalysis\Grid_Tuning_geometric.py in generate_records_df(records)
#      53         ],
#      54     )
# ---> 55     records_df = check_last_row(records_df)
#      56     return records_df
#      57
#
# ~\Documents\GitHub\huobi_Python\AlgoTrading\ParameterAnalysis\Grid_Tuning_geometric.py in check_last_row(records_df)
#      32 def check_last_row(records_df):
#      33     temp = records_df.tail(1)
# ---> 34     last_action = temp.iloc[0]["Action"]
#      35     if last_action == "Buying":
#      36         records_df = records_df.iloc[:-1, :]
#
# ~\Anaconda3\envs\AlgoTrading\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# ~\Anaconda3\envs\AlgoTrading\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1499
#    1500             # validate the location
# -> 1501             self._validate_integer(key, axis)
#    1502
#    1503             return self.obj._ixs(key, axis=axis)
#
# ~\Anaconda3\envs\AlgoTrading\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    1442         len_axis = len(self.obj._get_axis(axis))
#    1443         if key >= len_axis or key < -len_axis:
# -> 1444             raise IndexError("single positional indexer is out-of-bounds")
#    1445
#    1446     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds

# %%
import numpy as np

# records_df = records_df.sort_values(by="Hour", ascending=True)
records_df["TransactionInterval"] = records_df["Hour"].diff()
records_df = records_df.dropna()
records_df.loc[:, "TransactionInterval"] = records_df["TransactionInterval"].apply(
    lambda x: x.seconds
)
records_df
# Out:
# C:\Users\bizjun\Anaconda3\envs\AlgoTrading\lib\site-packages\pandas\core\indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#      Action  Price    n    Cash  Profit    LowerBound    UpperBound   Rate  \
# 1   Selling  58448  0.0  100440     440  52107.962513  60023.544671  0.006
# 2    Buying  59056  1.0   41384  -58616  52107.952480  60023.858665  0.006
# 3   Selling  59434  0.0  100818     818  52118.791899  60379.114287  0.006
# 4    Buying  60090  1.0   40728  -59272  52118.759097  60379.582934  0.006
# 5   Selling  60695  0.0  101423    1423  54322.625167  60744.777222  0.006
# 6    Buying  60722  1.0   40701  -59299  54340.393522  60742.395282  0.006
# 7   Selling  62377  0.0  103078    3078  55695.325335  62463.517689  0.006
# 8    Buying  62561  1.0   40516  -59484  55642.790703  62607.168072  0.006
# 9   Selling  62960  0.0  103477    3477  55547.776090  62963.954444  0.006
# 10   Buying  63006  1.0   40471  -59529  55526.311871  63039.004301  0.006
