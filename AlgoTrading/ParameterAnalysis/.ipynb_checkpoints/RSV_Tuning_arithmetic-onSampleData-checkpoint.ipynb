# %%
# %load_ext lab_black
# %config Completer.use_jedi = False
import pandas as pd
from Grid_Tuning_arithmetic_RSV import grid_trading, speedy_grid_trading
from tqdm import tqdm
import time

# %%
# %%time

# FILENAME = "Binance_BTC_1m.csv"
# data = pd.read_csv(FILENAME)
# optimization_arithmetic=[]
# for interval_for_bounds in tqdm(range(5,20)):
#     for sd in range(2,5):
#         records_df, final_profit = speedy_grid_trading(
#             data, INTERVAL_FOR_BOUNDS=interval_for_bounds * 24 * 60, SD_PARAMETER=sd,
#         )
#         optimization_arithmetic.append([final_profit, "", interval_for_bounds, sd])

# %%
# %%time
# FILENAME = "Mild_Fluctuate_data.csv"
FILENAME = "Increasing_Data.csv"
data = pd.read_csv(FILENAME)
optimization_RSV=[]
# for interval_for_rsv in tqdm(range(10, 60,5)):
#     for interval_for_bounds in range(5, 20,5):
#         for sd_parameter in range(2,5):
#             records_df, final_profit = grid_trading(
#                 data, INTERVALS_FOR_RSV=interval_for_rsv, INTERVAL_FOR_BOUNDS=interval_for_bounds * 24 * 60, SD_PARAMETER=sd_parameter,
#             )
#             optimization_RSV.append([final_profit, interval_for_rsv, interval_for_bounds, sd_parameter])
#             print(time.ctime())
# Out:
# Wall time: 70 ms

# %%
optimization_df = pd.DataFrame(
    optimization_RSV,
    columns=["FinalProfit", "IntervalForRSV", "IntervalForBounds", "SDParameter",],
)

# %%
# optimization_df.to_excel("Training_ArithmeticSequence_RSV.xlsx")
# optimization_df = pd.read_excel("Training.xlsx")
optimization_df
# Out:
# Empty DataFrame
# Columns: [FinalProfit, IntervalForRSV, IntervalForBounds, SDParameter]
# Index: []

# %%
df = optimization_df[
    optimization_df["FinalProfit"] == optimization_df["FinalProfit"].max()
]
SDParameter = df["SDParameter"].unique()
IntervalForBounds = df["IntervalForBounds"].unique()
IntervalForRSV = df["IntervalForRSV"].unique()
FinalProfit = df["FinalProfit"].unique()

# %%
SDParameter
# Out:
# array([2], dtype=int64)

# %%
IntervalForBounds
# Out:
# array([15], dtype=int64)

# %%
IntervalForRSV
# Out:
# array([40], dtype=int64)

# %%
FinalProfit
# Out:
# array([199755], dtype=int64)

# %%
# %%time
from Grid_Tuning_arithmetic_RSV import grid_trading

records_df, final_profit = grid_trading(
    data, INTERVALS_FOR_RSV=40, INTERVAL_FOR_BOUNDS=15 * 24 * 60, SD_PARAMETER=2,
)
records_df["Hour"] = pd.to_datetime(records_df["Hour"])
records_df
# Out:
# Wall time: 1.71 s
#      Action  Price    n    Cash  Profit    LowerBound    UpperBound  \
# 0    Buying  58008  1.0   41992  -58008  51953.683087  60367.202735
# 1   Selling  58836  0.0  100828     828  52107.512470  60029.738970
# 2    Buying  59434  1.0   41394  -58606  52107.462408  60030.118259
# 3   Selling  60335  0.0  101729    1729  54321.763843  60744.828936
# 4    Buying  60722  1.0   41007  -58993  54340.393522  60742.395282
# 5   Selling  62377  0.0  103384    3384  55695.325335  62463.517689
# 6    Buying  62561  1.0   40822  -59178  55642.790703  62607.168072
# 7   Selling  62632  0.0  103455    3455  55594.792775  62793.838529
# 8    Buying  62778  1.0   40677  -59323  55578.380604  62848.868137
# 9   Selling  62830  0.0  103507    3507  55556.662502  62928.385632
# 10   Buying  63006  1.0   40500  -59500  55526.311871  63039.004301
# 11   Buying  37315  2.0   25370  -74630  29307.694000  38943.652104
# 12  Selling  37329  0.0  100028      28  29530.593430  37588.598409
# 13   Buying  37590  2.0   24847  -75153  29525.753354  37608.349705
# 14  Selling  37641  0.0  100129     129  29502.459968  37736.003958
# 15   Buying  37853  2.0   24424  -75576  29489.905716  37866.632739
# 16  Selling  39344  0.0  103113    3113  29274.166187  39349.959540
# 17   Buying  39356  2.0   24402  -75598  29269.905411  39371.751444
# 18  Selling  45602  0.0  115605   15605  27851.951818  45614.780461
# 19   Buying  45567  2.0   24471  -75529  27852.503515  45620.678315
# 20  Selling  45921  0.0  116313   16313  28208.183695  46863.612527
# 21   Buying  46295  2.0   23723  -76277  28208.531950  46864.631725
# 22  Selling  47197  0.0  118117   18117  28303.947554  47227.027302
# 23   Buying  47513  2.0   23092  -76908  28402.109870  47518.711368
# 24  Selling  47617  0.0  118327   18327  28497.764276  47803.366314
# 25   Buying  47955  2.0   22417  -77583  28560.824490  47961.853194
# 26  Selling  48473  0.0  119364   19364  29700.278469  50773.076863
# 27   Buying  48910  2.0   21543  -78457  29700.748255  50774.007630
# 28  Selling  49013  0.0  119569   19569  29869.519720  51166.077517
#
#       LowerGrid    UpperGrid                Hour
# 0    367.584004  1315.119925 2021-03-29 23:59:00
# 1    792.222650   792.222650 2021-03-30 18:02:00
# 2    792.265585   792.265585 2021-03-30 18:03:00
# 3    642.306509   642.306509 2021-10-04 12:20:00
# 4    458.419917   821.980435 2021-10-04 12:41:00
# 5   1353.638471     0.000000 2021-04-14 22:14:00
# 6   1392.875474     0.000000 2021-04-15 01:59:00
# 7   1439.809151     0.000000 2021-04-15 08:37:00
# 8   1454.097507     0.000000 2021-04-15 10:22:00
# 9   1474.344626     0.000000 2021-04-15 12:45:00
# 10  1502.538486     0.000000 2021-04-15 16:17:00
# 11   710.105519  1217.086101 2021-01-29 23:59:00
# 12  1611.600996     0.000000 2021-05-02 17:22:00
# 13  1616.519270     0.000000 2021-05-02 17:57:00
# 14  1646.708798     0.000000 2021-05-02 21:34:00
# 15  1675.345405     0.000000 2021-06-02 00:57:00
# 16  2015.158671     0.000000 2021-07-02 07:10:00
# 17  2020.369207     0.000000 2021-07-02 07:40:00
# 18  3552.565729     0.000000 2021-10-02 20:32:00
# 19  3553.634960     0.000000 2021-10-02 20:37:00
# 20  3512.699370   218.386396 2021-11-02 19:53:00
# 21  3731.219955     0.000000 2021-11-02 19:54:00
# 22  3784.615950     0.000000 2021-12-02 00:48:00
# 23  3823.320300     0.000000 2021-12-02 04:51:00
# 24  3861.120408     0.000000 2021-12-02 08:56:00
# 25  3880.205741     0.000000 2021-12-02 11:11:00
# 26  4214.559679     0.000000 2021-02-14 14:36:00
# 27  4214.651875     0.000000 2021-02-14 14:37:00
# 28  4259.311559     0.000000 2021-02-14 21:18:00

# %%
# %%time
import numpy as np

# records_df = records_df.sort_values(by="Hour", ascending=True)
records_df["TransactionInterval"] = records_df["Hour"].diff()
records_df = records_df.dropna()
records_df.loc[:, "TransactionInterval"] = records_df["TransactionInterval"].apply(
    lambda x: x.seconds
)
records_df
# Out:
# Wall time: 6 ms
# C:\Users\bizjun\Anaconda3\envs\AlgoTrading\lib\site-packages\pandas\core\indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#      Action  Price    n    Cash  Profit    LowerBound    UpperBound  \
# 1   Selling  58836  0.0  100828     828  52107.512470  60029.738970
# 2    Buying  59434  1.0   41394  -58606  52107.462408  60030.118259
# 3   Selling  60335  0.0  101729    1729  54321.763843  60744.828936
# 4    Buying  60722  1.0   41007  -58993  54340.393522  60742.395282
# 5   Selling  62377  0.0  103384    3384  55695.325335  62463.517689
# 6    Buying  62561  1.0   40822  -59178  55642.790703  62607.168072
# 7   Selling  62632  0.0  103455    3455  55594.792775  62793.838529
# 8    Buying  62778  1.0   40677  -59323  55578.380604  62848.868137
# 9   Selling  62830  0.0  103507    3507  55556.662502  62928.385632
# 10   Buying  63006  1.0   40500  -59500  55526.311871  63039.004301
# 11   Buying  37315  2.0   25370  -74630  29307.694000  38943.652104
# 12  Selling  37329  0.0  100028      28  29530.593430  37588.598409
# 13   Buying  37590  2.0   24847  -75153  29525.753354  37608.349705
# 14  Selling  37641  0.0  100129     129  29502.459968  37736.003958
# 15   Buying  37853  2.0   24424  -75576  29489.905716  37866.632739
# 16  Selling  39344  0.0  103113    3113  29274.166187  39349.959540
# 17   Buying  39356  2.0   24402  -75598  29269.905411  39371.751444
# 18  Selling  45602  0.0  115605   15605  27851.951818  45614.780461
# 19   Buying  45567  2.0   24471  -75529  27852.503515  45620.678315
# 20  Selling  45921  0.0  116313   16313  28208.183695  46863.612527
# 21   Buying  46295  2.0   23723  -76277  28208.531950  46864.631725
# 22  Selling  47197  0.0  118117   18117  28303.947554  47227.027302
# 23   Buying  47513  2.0   23092  -76908  28402.109870  47518.711368
# 24  Selling  47617  0.0  118327   18327  28497.764276  47803.366314
# 25   Buying  47955  2.0   22417  -77583  28560.824490  47961.853194
# 26  Selling  48473  0.0  119364   19364  29700.278469  50773.076863
# 27   Buying  48910  2.0   21543  -78457  29700.748255  50774.007630
# 28  Selling  49013  0.0  119569   19569  29869.519720  51166.077517
#
#       LowerGrid    UpperGrid                Hour  TransactionInterval
# 1    792.222650   792.222650 2021-03-30 18:02:00                64980
# 2    792.265585   792.265585 2021-03-30 18:03:00                   60
# 3    642.306509   642.306509 2021-10-04 12:20:00                65820
# 4    458.419917   821.980435 2021-10-04 12:41:00                 1260
# 5   1353.638471     0.000000 2021-04-14 22:14:00                34380
# 6   1392.875474     0.000000 2021-04-15 01:59:00                13500
# 7   1439.809151     0.000000 2021-04-15 08:37:00                23880
# 8   1454.097507     0.000000 2021-04-15 10:22:00                 6300
# 9   1474.344626     0.000000 2021-04-15 12:45:00                 8580
# 10  1502.538486     0.000000 2021-04-15 16:17:00                12720
# 11   710.105519  1217.086101 2021-01-29 23:59:00                27720
# 12  1611.600996     0.000000 2021-05-02 17:22:00                62580
# 13  1616.519270     0.000000 2021-05-02 17:57:00                 2100
# 14  1646.708798     0.000000 2021-05-02 21:34:00                13020
# 15  1675.345405     0.000000 2021-06-02 00:57:00                12180
# 16  2015.158671     0.000000 2021-07-02 07:10:00                22380
# 17  2020.369207     0.000000 2021-07-02 07:40:00                 1800
# 18  3552.565729     0.000000 2021-10-02 20:32:00                46320
# 19  3553.634960     0.000000 2021-10-02 20:37:00                  300
# 20  3512.699370   218.386396 2021-11-02 19:53:00                83760
# 21  3731.219955     0.000000 2021-11-02 19:54:00                   60
# 22  3784.615950     0.000000 2021-12-02 00:48:00                17640
# 23  3823.320300     0.000000 2021-12-02 04:51:00                14580
# 24  3861.120408     0.000000 2021-12-02 08:56:00                14700
# 25  3880.205741     0.000000 2021-12-02 11:11:00                 8100
# 26  4214.559679     0.000000 2021-02-14 14:36:00                12300
# 27  4214.651875     0.000000 2021-02-14 14:37:00                   60
# 28  4259.311559     0.000000 2021-02-14 21:18:00                24060

# %%
# records_df.to_excel("TransactionHistory_ArithmeticSequence_RSV.xlsx")
