# %%
# %load_ext lab_black
# %config Completer.use_jedi = False
import pandas as pd
from Tuning_arithmetic_RSV_GridNumber import grid_trading, speedy_grid_trading
from tqdm import tqdm
import time
# Out:
# The lab_black extension is already loaded. To reload it, use:
#   %reload_ext lab_black

# %%
# %%time

# FILENAME = "Binance_BTC_1m.csv"
# data = pd.read_csv(FILENAME)
# optimization_arithmetic=[]
# for interval_for_bounds in tqdm(range(5,20)):
#     for sd in range(2,5):
#         records_df, final_profit = speedy_grid_trading(
#             data, INTERVAL_FOR_BOUNDS=interval_for_bounds * 24 * 60, SD_PARAMETER=sd,
#         )
#         optimization_arithmetic.append([final_profit, "", interval_for_bounds, sd])
# Out:
# Wall time: 0 ns

# %%
# %%time
# FILENAME = "Mild_Fluctuate_data.csv"
# FILENAME = "Increasing_Data.csv"
# FILENAME = "Binance_BTC_1m.csv"
FILENAME = "Decreasing_Data.csv"
data = pd.read_csv(FILENAME)
data
# optimization_RSV=[]
# for interval_for_rsv in tqdm(range(10, 60,5)):
#     for interval_for_bounds in range(5, 20,5):
#         for sd_parameter in range(2,5):
#             for grid_number in range(6, 40,4):
#                 records_df, final_profit = grid_trading(
#                     data, INTERVALS_FOR_RSV=interval_for_rsv, INTERVAL_FOR_BOUNDS=interval_for_bounds * 24 * 60, SD_PARAMETER=sd_parameter,GRID_NUMBER=grid_number
#                 )
#                 optimization_RSV.append([final_profit, interval_for_rsv, interval_for_bounds, sd_parameter, grid_number])
#                 print(time.ctime())
# for grid_number in range(6, 40,4):
#     records_df, final_profit = grid_trading(
#         data, INTERVALS_FOR_RSV=30, INTERVAL_FOR_BOUNDS=15 * 24 * 60, SD_PARAMETER=2,GRID_NUMBER=grid_number
#     )
#     optimization_RSV.append([final_profit, 30, 15, 2, grid_number])
#     print(time.ctime())
# Out:
# Wall time: 15 ms
#       Unnamed: 0  Unnamed: 0.1       TimeStamp      Open      High       Low  \
# 0         127500        136740  2021/2/22 7:32  57472.29  57480.01  57437.93
# 1         127501        136741  2021/2/22 7:33  57447.38  57510.00  57446.01
# 2         127502        136742  2021/2/22 7:34  57461.21  57474.28  57448.93
# 3         127503        136743  2021/2/22 7:35  57453.74  57490.62  57441.13
# 4         127504        136744  2021/2/22 7:36  57449.41  57507.87  57449.41
# ...          ...           ...             ...       ...       ...       ...
# 9995      137495        109374   2021/2/3 6:07  35657.91  35665.27  35635.51
# 9996      137496        109375   2021/2/3 6:08  35637.32  35690.00  35637.32
# 9997      137497        109376   2021/2/3 6:09  35642.89  35660.95  35642.88
# 9998      137498        109377   2021/2/3 6:10  35655.41  35656.62  35611.25
# 9999      137499        109378   2021/2/3 6:11  35613.14  35624.21  35584.33
#
#          Close     Volume
# 0     57448.37  38.845894
# 1     57461.22  42.609888
# 2     57453.74  16.395970
# 3     57449.54  28.681314
# 4     57495.82  42.027890
# ...        ...        ...
# 9995  35640.62  20.562739
# 9996  35644.35  31.650692
# 9997  35655.41  22.989269
# 9998  35613.14  23.330931
# 9999  35587.97  30.461753
#
# [10000 rows x 8 columns]

# %%
# optimization_df = pd.DataFrame(
#     optimization_RSV,
#     columns=[
#         "FinalProfit",
#         "IntervalForRSV",
#         "IntervalForBounds",
#         "SDParameter",
#         "GridNumber",
#     ],
# )

# %%
# optimization_df.to_excel("Training_ArithmeticSequence_RSV_GridNumber_Updated.xlsx")
# optimization_df = pd.read_excel("Training_ArithmeticSequence_RSV_GridNumber.xlsx")
# optimization_df

# %%
# df = optimization_df[
#     optimization_df["FinalProfit"] == optimization_df["FinalProfit"].max()
# ]
# SDParameter = df["SDParameter"].unique()
# IntervalForBounds = df["IntervalForBounds"].unique()
# IntervalForRSV = df["IntervalForRSV"].unique()
# FinalProfit = df["FinalProfit"].unique()
# GridNumber = df["GridNumber"].unique()

# %%
# sd = SDParameter
# sd

# %%
# ifb = IntervalForBounds
# ifb

# %%
# ifrsv = IntervalForRSV
# ifrsv

# %%
# fp = FinalProfit
# fp

# %%
# gn = GridNumber
# gn

# %%
FILENAME = "Decreasing_Data.csv"
data = pd.read_csv(FILENAME)
data
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1        TimeStamp      Open  \
# 0            5000        125000          135620  2021/2/21 12:52  56530.69
# 1            5001        125001          135621  2021/2/21 12:53  56526.38
# 2            5002        125002          135622  2021/2/21 12:54  56550.00
# 3            5003        125003          135623  2021/2/21 12:55  56604.55
# 4            5004        125004          135624  2021/2/21 12:56  56572.71
# ...           ...           ...             ...              ...       ...
# 14995       19995        139995          113194   2021/2/5 21:47  37963.72
# 14996       19996        139996          113195   2021/2/5 21:48  37978.08
# 14997       19997        139997          113196   2021/2/5 21:49  38127.43
# 14998       19998        139998          113197   2021/2/5 21:50  38172.02
# 14999       19999        139999          113198   2021/2/5 21:51  38137.56
#
#            High       Low     Close      Volume
# 0      56571.77  56523.90  56526.38   17.928238
# 1      56590.00  56517.00  56550.01   25.635945
# 2      56640.00  56542.94  56604.54   19.254883
# 3      56613.83  56541.25  56569.16   18.708440
# 4      56631.11  56544.52  56623.46   19.152437
# ...         ...       ...       ...         ...
# 14995  37999.68  37963.71  37978.09   89.867376
# 14996  38130.17  37971.29  38130.00  178.493656
# 14997  38198.78  38084.69  38172.03  211.731013
# 14998  38172.03  38079.23  38140.94  158.094804
# 14999  38141.20  38075.29  38110.48   92.377754
#
# [15000 rows x 9 columns]

# %%
# %%time
from Tuning_arithmetic_RSV_GridNumber import grid_trading, speedy_grid_trading
records_df, final_profit = grid_trading(
    data, INTERVALS_FOR_RSV=30, INTERVAL_FOR_BOUNDS=15 * 24 * 60, SD_PARAMETER=2,GRID_NUMBER=6,
)
records_df["Hour"] = pd.to_datetime(records_df["Hour"])
records_df
# Out:
# Wall time: 15 ms
#     Action  Price    n    Cash  Profit    LowerBound    UpperBound  \
# 0   Buying  49180  2.0    1640  -98360  39090.312214  60231.227947
