# %%
# %load_ext lab_black
# %config Completer.use_jedi = False
import pandas as pd

f = "Binance_BTC_1m.csv"
data = pd.read_csv(f)
data
N = 24 * 60
M = 2
CLOSE = "Close"
TIMESTAMP = "TimeStamp"


def calc_RSV(prices, n=9):
    C = prices
    H = prices.rolling(n).max()
    L = prices.rolling(n).min()
    RSV = (C - L) / (H - L)
    return RSV


RSV = calc_RSV(data["Close"])
data["RSV"] = RSV
# Out:
# The lab_black extension is already loaded. To reload it, use:
#   %reload_ext lab_black

# %%
def calc_bbands(prices, n=N, m=M):
    middle_vals = prices.rolling(n).mean()
    std_vals = prices.rolling(n).std(ddof=0)
    upper_vals = middle_vals + m * std_vals
    lower_vals = middle_vals - m * std_vals
    return upper_vals, middle_vals, lower_vals


upper, middle, lower = calc_bbands(data["Close"])
data["boll_upper"] = upper
# data['boll_middle'] = middle
data["boll_lower"] = lower
data = data.dropna()
data.reset_index(drop=True, inplace=True)
data
# Out:
#                   TimeStamp      Open      High       Low     Close  \
# 0       2020-11-20 01:22:00  17939.46  17953.97  17936.99  17941.20
# 1       2020-11-20 01:23:00  17942.22  17953.00  17939.53  17941.17
# 2       2020-11-20 01:24:00  17941.48  17952.92  17941.48  17948.06
# 3       2020-11-20 01:25:00  17948.06  17960.00  17947.68  17958.79
# 4       2020-11-20 01:26:00  17958.80  17974.04  17949.02  17957.02
# ...                     ...       ...       ...       ...       ...
# 197919  2021-04-06 22:38:00  57798.97  57831.81  57716.14  57758.10
# 197920  2021-04-06 22:39:00  57758.09  57825.10  57745.28  57818.77
# 197921  2021-04-06 22:40:00  57818.77  57860.83  57760.66  57783.63
# 197922  2021-04-06 22:41:00  57783.62  57828.57  57760.00  57808.29
# 197923  2021-04-06 22:42:00  57808.29  57808.30  57709.09  57777.17
#
#            Volume       RSV    boll_upper    boll_lower
# 0       31.299947  1.000000  18090.136990  17467.164663
# ...

# %%
import matplotlib.pyplot as plt

# %matplotlib inline
fig, ax = plt.subplots(figsize=(30, 10))
# plt.ylim(0, 100)
data[[CLOSE]].plot(ax=ax)
# Out:
# <AxesSubplot:>

# %%
BEGINNING_CASH = 100000


def buying(
    last_price, trading_buying_price, cash, n, r, records, price, time, index,
):
    n += cash // trading_buying_price
    cash -= trading_buying_price * n
    profit = cash - BEGINNING_CASH
    records.append(["Buying", -round(price), n, round(cash), round(profit), time])
    last_price = price
    return last_price, cash, n, profit, records, index + 1

# %%
def selling(last_price, trading_selling_price, cash, n, r, records, price, time, index):
    cash += trading_selling_price * n
    profit = cash - BEGINNING_CASH
    records.append(["Selling", round(price), 0, round(cash), round(profit), time])
    last_price = price
    n = 0
    start_index = index + 1
    upper_bound = row["boll_upper"]
    lower_bound = row["boll_lower"]
    return last_price, cash, n, profit, records, start_index

# %%
def transact(price, last_price, cash, n, profit, records, time, index):
    trading_buying_price = price * (1 + FEE)
    trading_selling_price = price * (1 - FEE)
    if last_price == 0 or (
        n == 0
        and trading_buying_price <= last_price * (1 - r)
        and cash - trading_buying_price > 0
    ):
        last_price, cash, n, profit, records, index = buying(
            last_price, trading_buying_price, cash, n, r, records, price, time, index,
        )
    elif n > 0 and trading_selling_price >= last_price * (1 + r):
        last_price, cash, n, profit, records, index = selling(
            last_price, trading_selling_price, cash, n, r, records, price, time, index
        )
    return last_price, cash, n, profit, records, index

# %%
FEE = 0.005
records = []
profit = 0
cash = BEGINNING_CASH
n = 0
last_price = 0
upper_bound = data.loc[0]["boll_upper"]
lower_bound = data.loc[0]["boll_lower"]
start_index = 0
r = 0.005


def get_profit_by_RSV(last_price, cash, n, profit, records, start_index):
    for index, row in data[start_index:].iterrows():
        time = row[TIMESTAMP]
        price = row[CLOSE]
        if lower_bound <= price <= upper_bound:
            if last_price < lower_bound:
                last_price = 0
            last_price, cash, n, profit, records,start_index = transact(
                price, last_price, cash, n, profit, records, time,index
            )
            break
    return last_price, cash, n, profit, records, start_index


while start_index < len(data):
    last_price, cash, n, profit, records, start_index = get_profit_by_RSV(
        last_price, cash, n, profit, records, start_index
    )
    print(profit, cash, start_index)
# Out:
# -90154.53 9845.470000000001 1
# -90154.53 9845.470000000001 1
# -90154.53 9845.470000000001 1
# -90154.53 9845.470000000001 1
# -90154.53 9845.470000000001 1
# -90154.53 9845.470000000001 1
# -90154.53 9845.470000000001 1
# -90154.53 9845.470000000001 1
# -90154.53 9845.470000000001 1
# -90154.53 9845.470000000001 1
# -90154.53 9845.470000000001 1
# -90154.53 9845.470000000001 1
# -90154.53 9845.470000000001 1
# -90154.53 9845.470000000001 1
# -90154.53 9845.470000000001 1
# -90154.53 9845.470000000001 1
# -90154.53 9845.470000000001 1
# -90154.53 9845.470000000001 1
# -90154.53 9845.470000000001 1
# -90154.53 9845.470000000001 1
# -90154.53 9845.470000000001 1
# -90154.53 9845.470000000001 1
# -90154.53 9845.470000000001 1
# -90154.53 9845.470000000001 1
# -90154.53 9845.470000000001 1
# -90154.53 9845.470000000001 1
# -90154.53 9845.470000000001 1
# -90154.53 9845.470000000001 1
# -90154.53 9845.470000000001 1
# -90154.53 9845.470000000001 1
# -90154.53 9845.470000000001 1
# ...

# %%
#     print(f"profit: {round(profit)}, records: {len(records)}, lower_bound: {round(lower_bound)}, upper_bound: {round(upper_bound)}, cash: {round(cash)}, n: {n}, last_price: {round(last_price)}, start_index: {start_index}\n")
#     records_df = pd.DataFrame(
#         records, columns=["Action", "Price", "n", "Cash", "Profit", "Hour"]
#     )
#     print(records_df, "\n")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-87-d86d7e0a0407> in <module>
#       6
#       7 while start_index < len(data):
# ----> 8     get_profit_by_RSV()
#
# <ipython-input-86-93066b601621> in get_profit_by_RSV()
#      11
#      12 def get_profit_by_RSV():
# ---> 13     for index, row in data[start_index:].iterrows():
#      14         time = row[TIMESTAMP]
#      15         price = row[CLOSE]
#
# ~\Anaconda3\envs\AlgoTrading\lib\site-packages\pandas\core\frame.py in iterrows(self)
#    1069         klass = self._constructor_sliced
#    1070         for k, v in zip(self.index, self.values):
# -> 1071             s = klass(v, index=columns, name=k)
#    1072             yield k, s
#    1073
#
# ~\Anaconda3\envs\AlgoTrading\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
# ...

# %%
# %%time
# def get_profit(r, records, profit, cash, lower_bound, upper_bound,n, last_price,):
#     for index, row in data.iterrows():
#         time = row[TIMESTAMP]
#         price = row[CLOSE]
#         if lower_bound <= price <= upper_bound:
#             if last_price < lower_bound:
#                 last_price=0
#             trading_buying_price = price * (1 + fee)
#             trading_selling_price = price * (1 - fee)
#             if last_price==0 or (n == 0 and price <= last_price * (1 - r) and cash - trading_buying_price > 0):
#                 n += cash // trading_buying_price
#                 cash -= trading_buying_price * n
#                 profit = cash - 100000
#                 records.append(
#                     ["Buying", -round(price), n, round(cash), round(profit), time]
#                 )
#                 last_price = price
#             elif n > 0 and price >= last_price * (1 + r):
#                 cash += trading_selling_price * n
#                 profit = cash - 100000
#                 records.append(
#                     ["Selling", round(price), 0, round(cash), round(profit), time]
#                 )
#                 last_price = price
#                 n = 0
#     return profit, records, cash, n, last_price
# fee = 0.002
# upper_bound=66583.747399
# lower_bound=9499.281743
# profit,records,cash,n, last_price=get_profit(0.005, [],0,upper_bound, lower_bound,80000,0,0)
# records_df = pd.DataFrame(
#     records, columns=["Action", "Price", "n", "Cash", "Profit", "Hour"]
# )
# print(profit)
# records_df
# Out:
# -32104.164680999995
# Wall time: 11.8 s
#      Action  Price    n   Cash  Profit                 Hour
# 0    Buying -17941  3.0  12653  -87347  2020-11-20 01:22:00
# 1   Selling  18074  0.0  66766  -33234  2020-11-20 05:26:00
# 2    Buying -17974  3.0  12737  -87263  2020-11-20 05:31:00
# 3   Selling  18065  0.0  66823  -33177  2020-11-20 12:26:00
# 4    Buying -17969  3.0  12809  -87191  2020-11-22 19:29:00
# 5   Selling  18064  0.0  66892  -33108  2020-11-22 20:15:00
# 6    Buying -17966  3.0  12888  -87112  2020-11-22 20:25:00
# 7   Selling  18060  0.0  66959  -33041  2020-11-22 20:28:00
# 8    Buying -17800  3.0  13452  -86548  2020-11-26 11:30:00
# 9   Selling  17896  0.0  67033  -32967  2020-11-26 11:47:00
# 10   Buying -17781  3.0  13583  -86417  2020-11-26 12:01:00
# 11  Selling  17919  0.0  67234  -32766  2020-11-26 12:03:00
# 12   Buying -17829  3.0  13639  -86361  2020-11-26 12:37:00
# 13  Selling  17921  0.0  67294  -32706  2020-11-26 13:49:00
# ...

# %%
# %%time
# import numpy as np
# from tqdm import tqdm
# optimization_r=[]
# fee = 0.002
# for r in tqdm(np.arange(fee,0.1,0.001)):
#     records=[]
#     profit=0
#     cash=100000
#     n=0
#     last_price=0
#     for lower_bound in range(30000, 60000,10000):
#         upper_bound=lower_bound+10000
# #         print(f"Lower Bound: {lower_bound}, Upper Bound: {upper_bound}, Profit: {profit}, Cash: {cash}, Number of coins: {n}, Last Price: {last_price}")
#         profit,records,cash,n, last_price=get_profit(r, records,profit,cash, lower_bound, upper_bound,n, last_price,)
#     optimization_r.append([r, profit])
# optimization_r_df = pd.DataFrame(optimization_r, columns=["Rate", "Profit"])
# pd.set_option("display.max_rows", None, "display.max_columns", None)
# # print(optimization_r_df)
# optimization_r_df[optimization_r_df["Profit"] == optimization_r_df["Profit"].max()]

# %%
# optimization_r_df

# %%
# %%time
r=0.042
fee = 0.002
records=[]
profit=0
cash=100000
n=0
last_price=0
for lower_bound in range(30000, 60000,10000):
    upper_bound=lower_bound+10000
    print(f"Lower Bound: {lower_bound}, Upper Bound: {upper_bound}, Profit: {profit}, Cash: {cash}, Number of coins: {n}, Last Price: {last_price}")
    profit,records,cash,n, last_price=get_profit(r, records,profit,cash, lower_bound, upper_bound,n, last_price,)
pd.set_option("display.max_rows", None, "display.max_columns", None)
records_df = pd.DataFrame(
    records, columns=["Action", "Price", "n", "Cash", "Profit", "Hour"]
)
print(profit)
records_df
# Out:
# Lower Bound: 30000, Upper Bound: 40000, Profit: 0, Cash: 100000, Number of coins: 0, Last Price: 0
# Lower Bound: 40000, Upper Bound: 50000, Profit: 26877.630059999996, Cash: 126877.63006, Number of coins: 0, Last Price: 31316.79
# Lower Bound: 50000, Upper Bound: 60000, Profit: 36090.816899999976, Cash: 136090.81689999998, Number of coins: 0, Last Price: 41753.86
# 47569.182579999964
# Wall time: 1min 4s
#      Action  Price    n    Cash  Profit                 Hour
# 0    Buying -30099  3.0    9522  -90478  2021-01-02 20:20:00
# 1   Selling  31541  0.0  103957    3957  2021-01-02 21:59:00
# 2    Buying -30200  3.0   13175  -86825  2021-01-04 18:46:00
# 3   Selling  31646  0.0  107923    7923  2021-01-04 22:00:00
# 4    Buying -30275  3.0   16915  -83085  2021-01-05 13:52:00
# 5   Selling  31567  0.0  111428   11428  2021-01-05 17:30:00
# 6    Buying -30123  3.0   20880  -79120  2021-01-22 06:37:00
# 7   Selling  31444  0.0  115024   15024  2021-01-22 07:02:00
# ...
