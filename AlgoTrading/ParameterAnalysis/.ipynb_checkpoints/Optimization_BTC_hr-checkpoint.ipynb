# %%
# %load_ext lab_black
import pandas as pd
import json


f = open("histohour_BTC.json",)
data = json.load(f)
data = pd.DataFrame.from_dict(data["Data"]["Data"])
data = data[["time", "close"]]
f.close()
data
# Out:
# The lab_black extension is already loaded. To reload it, use:
#   %reload_ext lab_black
#             time     close
# 0     1611691200  32020.72
# 1     1611694800  32024.18
# 2     1611698400  32765.79
# 3     1611702000  32516.52
# 4     1611705600  32371.54
# ...          ...       ...
# 1996  1618876800  54710.74
# 1997  1618880400  54854.55
# 1998  1618884000  54235.44
# 1999  1618887600  54602.38
# 2000  1618891200  54829.94
#
# [2001 rows x 2 columns]

# %%
def get_profit(lower_limit, upper_limit):
    i = 0
    profit = 0
    records = []
    n = 0
    for index, row in data.iterrows():
        day = index
        price = row["close"]
        if i % 2 == 0:
            if row["RSI"] <= lower_limit and n == 0:
                profit -= price
                records.append(["Buying", -round(price), round(profit), day])
                n += 1
                i += 1
        else:
            if row["RSI"] >= upper_limit and n >= 0 and profit + price >= 1:
                profit += price
                records.append(["Selling", round(price), round(profit), day])
                n -= 1
                i += 1
    return profit


def calculation(data, window_length, lower_limit, upper_limit):
    delta = data["close"].diff()
    up, down = delta.copy(), delta.copy()
    up[up <= 1] = 0
    down[down >= 2] = 0
    roll_up1 = up.ewm(span=window_length).mean()
    roll_down1 = down.abs().ewm(span=window_length).mean()
    RS1 = roll_up1 / roll_down1
    RSI1 = 100.0 - (100.0 / (1.0 + RS1))
    data.loc[:, "RSI"] = RSI1
    data.loc[:, "TimeStamp"] = pd.to_datetime(data["time"], unit="s")
    data = data.set_index("TimeStamp")
    return get_profit(lower_limit, upper_limit)


calculation(data, 14, 50, 60)
# Out:
# -49882.219999999994

# %%
# %%time
from tqdm import tqdm
optimizations=[]
for window_length in tqdm(range(10, 20)):
    for lower_limit in range(10, 30):
        for upper_limit in range(80, 100):
            profit = calculation(data, window_length, lower_limit,upper_limit)
            optimizations.append([profit, window_length, lower_limit, upper_limit])
# Out:
# 100%|██████████| 10/10 [29:53<00:00, 179.33s/it]
# Wall time: 29min 53s

# %%
optimization_df = pd.DataFrame(
    optimizations, columns=["Profit", "WindowLength", "LowerLimit", "UpperLimit"]
)
pd.set_option("max_rows", 30)
optimization_df
# Out:
#         Profit  WindowLength  LowerLimit  UpperLimit
# 0    -53430.10            10          10          80
# 1    -53430.10            10          10          81
# 2    -53430.10            10          10          82
# 3    -50925.31            10          10          83
# 4    -49825.54            10          10          84
# ...        ...           ...         ...         ...
# 3995 -30682.82            19          29          95
# 3996 -30682.82            19          29          96
# 3997 -30682.82            19          29          97
# 3998 -30682.82            19          29          98
# 3999 -30682.82            19          29          99
#
# [4000 rows x 4 columns]

# %%
# optimization_df.to_excel("Profit_Optimization_BTC_hr.xlsx")

# %%
import numpy as np
from scipy.optimize import minimize, LinearConstraint

n_window_length = 1000
n_lower_limit = 100
n_upper_limit = 100
np.random.seed(10)
window_length = np.random.random(n_window_length)
window_length_available = np.random.randint(1, 1000, n_window_length)
window_length = np.random.random(n_window_length)
window_length_available = np.random.randint(1, 1000, n_window_length)
window_length = np.random.random(n_window_length)
window_length_available = np.random.randint(1, 1000, n_window_length)

# %%
from pulp import LpMaximize, LpProblem, LpStatus, lpSum, LpVariable
model = LpProblem(name="small-problem", sense=LpMaximize)
window_length = LpVariable(name="window_length", lowBound=0, upBound=1000,cat='Integer')
lower_limit = LpVariable(name="lower_limit", lowBound=0, upBound=100,cat='Integer')
upper_limit = LpVariable(name="upper_limit", lowBound=0, upBound=100,cat='Integer')

constraint = upper_limit-lower_limit>=1
obj_func = calculation(data, window_length,lower_limit,upper_limit)
model += obj_func
status = model.solve()
# print(f"status: {model.status}, {LpStatus[model.status]}")


# print(f"objective: {model.objective.value()}")


# for var in model.variables():
#     print(f"{var.name}: {var.value()}")




# for name, constraint in model.constraints.items():
#     print(f"{name}: {constraint.value()}")
# model.variables()

# model.variables()[0] is x

# model.variables()[1] is y

# model.solver
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-c5ec8fa41d52> in <module>
#       6
#       7 constraint = upper_limit-lower_limit>=1
# ----> 8 obj_func = calculation(data, window_length,lower_limit,upper_limit)
#       9 model += obj_func
#      10 status = model.solve()
#
# <ipython-input-25-21e0b710e582> in calculation(data, window_length, lower_limit, upper_limit)
#      29     down[down >= 2] = 0
#      30     down=down[1:]
# ---> 31     roll_up1 = up.ewm(span=window_length).mean()
#      32     roll_down1 = down.abs().ewm(span=window_length).mean()
#      33     RS1 = roll_up1 / roll_down1
#
# ~\Anaconda3\envs\AlgoTrading\lib\site-packages\pandas\core\generic.py in ewm(self, com, span, halflife, alpha, min_periods, adjust, ignore_na, axis, times)
#   11286     ) -> ExponentialMovingWindow:
#   11287         axis = self._get_axis_number(axis)
# ...

# %%
# Create the model
model = LpProblem(name="small-problem", sense=LpMaximize)

# Initialize the decision variables
x = LpVariable(name="x", lowBound=0)
y = LpVariable(name="y", lowBound=0)

# Add the constraints to the model
model += (2 * x + y <= 20, "red_constraint")
model += (4 * x - 5 * y >= -10, "blue_constraint")
model += (-x + 2 * y >= -2, "yellow_constraint")
model += (-x + 5 * y == 15, "green_constraint")

# Add the objective function to the model
model += lpSum([x, 2 * y])

# Solve the problem
status = model.solve(solver=GLPK(msg=False))

# %%
from ortools.linear_solver import pywraplp


def LinearProgrammingExample():
    solver = pywraplp.Solver.CreateSolver("GLOP")
    window_length = solver.NumVar(0, 100, "window_length")
    lower_limit = solver.NumVar(0, 100, "lower_limit")
    upper_limit = solver.NumVar(0, 100, "upper_limit")

    print("Number of variables =", solver.NumVariables())

    solver.Add(upper_limit-lower_limit>=2)

    print("Number of constraints =", solver.NumConstraints())

    data=get_data()
    solver.Maximize(calculation(data,window_length,lower_limit,upper_limit))

    status = solver.Solve()

    if status == pywraplp.Solver.OPTIMAL:
        print("Solution:")
        print("Objective value =", solver.Objective().Value())
        print("window_length =", window_length.solution_value())
        print("lower_limit =", lower_limit.solution_value())
        print("upper_limit =", upper_limit.solution_value())
    else:
        print("The problem does not have an optimal solution.")

    print("\nAdvanced usage:")
    print("Problem solved in %f milliseconds" % solver.wall_time())
    print("Problem solved in %d iterations" % solver.iterations())


LinearProgrammingExample()
# Out:
# Number of variables = 3
# Number of constraints = 1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-e50cf1e2499f> in <module>
#      33
#      34
# ---> 35 LinearProgrammingExample()
#
# <ipython-input-23-e50cf1e2499f> in LinearProgrammingExample()
#      15
#      16     data=get_data()
# ---> 17     solver.Maximize(calculation(data,window_length,lower_limit,upper_limit))
#      18
#      19     status = solver.Solve()
#
# <ipython-input-21-9b090c7943fe> in calculation(data, window_length, lower_limit, upper_limit)
#      27     up[up <= 1] = 0
#      28     down[down >= 2] = 0
# ---> 29     roll_up1 = up.ewm(span=window_length).mean()
#      30     roll_down1 = down.abs().ewm(span=window_length).mean()
#      31     RS1 = roll_up1 / roll_down1
#
# ...
