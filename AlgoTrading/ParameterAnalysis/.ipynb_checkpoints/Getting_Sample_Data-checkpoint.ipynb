# %%
# %load_ext lab_black
# %config Completer.use_jedi = False
import pandas as pd
from tqdm import tqdm
import time
# Out:
# The lab_black extension is already loaded. To reload it, use:
#   %reload_ext lab_black

# %%
FILENAME = "Binance_BTC_1m.csv"
data = pd.read_csv(FILENAME)
data = data[127500:135000]
data
# Out:
#         Unnamed: 0        TimeStamp      Open      High       Low     Close  \
# 127500      136740   2021/2/22 7:32  57472.29  57480.01  57437.93  57448.37
# 127501      136741   2021/2/22 7:33  57447.38  57510.00  57446.01  57461.22
# 127502      136742   2021/2/22 7:34  57461.21  57474.28  57448.93  57453.74
# 127503      136743   2021/2/22 7:35  57453.74  57490.62  57441.13  57449.54
# 127504      136744   2021/2/22 7:36  57449.41  57507.87  57449.41  57495.82
# ...            ...              ...       ...       ...       ...       ...
# 134995      145615  2021/2/28 11:27  45274.60  45391.57  45274.60  45387.13
# 134996      145616  2021/2/28 11:28  45378.61  45463.75  45375.45  45409.34
# 134997      145617  2021/2/28 11:29  45411.27  45443.75  45373.72  45388.83
# 134998      145618  2021/2/28 11:30  45389.16  45480.30  45383.34  45476.48
# 134999      145619  2021/2/28 11:31  45477.42  45511.42  45414.68  45431.88
#
#            Volume
# 127500  38.845894
# 127501  42.609888
# 127502  16.395970
# 127503  28.681314
# 127504  42.027890
# ...           ...
# 134995  31.120151
# 134996  31.740867
# 134997  26.950724
# 134998  54.306009
# 134999  61.717603
#
# [7500 rows x 7 columns]

# %%
import matplotlib.pyplot as plt

# %matplotlib inline
fig, ax = plt.subplots(figsize=(30, 10))
# plt.ylim(0, 100)
data[["Close"]].plot(ax=ax)
# Out:
# <AxesSubplot:>

# %%
# data.to_csv("Decreasing_Data.csv")
